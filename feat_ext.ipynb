# %%
from utils.config import path_config, feature_config
from utils.feature_extrcation import create_feature_set

# %%
# crate feature set and add labels
feature_df = create_feature_set(data_dir = path_config['data'],\
                        data_dir_list = path_config['data_dir_list'],\
                        colmuns = feature_config['feature_columns'])

# %%
# check feature set
feature_df.to_csv('model/train/output/feature_set/feature_set.csv')

# %%
feature_df
# Out:
#          zcr  rms_energy       mfcc0  ...   sp_rolloff        sp_bw  label
# 0   0.129532    0.052311 -242.176138  ...  3476.017253  1995.672451    cat
# 1   0.043464    0.038943 -308.997583  ...  2994.653320  2199.876642    cat
# 2   0.137801    0.041252 -326.570528  ...  5308.827652  2431.154565    cat
# 3   0.138109    0.069131 -231.478098  ...  3724.047852  2044.611521    cat
# 4   0.133045    0.004869 -434.236818  ...  6189.350382  2753.527084    cat
# ..       ...         ...         ...  ...          ...          ...    ...
# 54  0.063405    0.022350 -344.096339  ...  3473.634834  2012.792364    cow
# 55  0.027135    0.004478 -563.027931  ...  3551.175736  2381.889255    cow
# 56  0.081049    0.056109 -262.340862  ...  3025.816279  1596.516039    cow
# 57  0.098076    0.043554 -275.326180  ...  3977.668427  1986.941642    cow
# 58  0.033941    0.005076 -489.115113  ...  1961.624727  1918.374373    cow
#
# [518 rows x 19 columns]
